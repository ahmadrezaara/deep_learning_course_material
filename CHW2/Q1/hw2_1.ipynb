# %%
# Feel free to import any other libraries and modules.
import numpy as np
import matplotlib.pyplot as plt
import torch
from torchvision import datasets, transforms
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from torch import nn

# %% [markdown]
# # Part One: Optimization Algorithms
# ## 1. Gradient Descent
# The Gradient Descent (GD) algorithm finds the minimum of a given
# function by taking small steps along the function's gradient:
#
# >$\Theta \leftarrow \Theta_0$
#
# >**while** stop condition not met **do**
#
# >$~~~~$$\Theta \leftarrow \Theta - \alpha \nabla_\Theta f(\Theta)$
#
# >**end while**
#
# where $f$ is the function to minimize, $\nabla_\Theta f(\Theta)$
# denotes $f$'s gradient at $\Theta$ and $\alpha$ is the learning rate.
#
# **Task1:** Implement the GD algorithm as a function:
#
#   \begin{equation}
#       \Theta_{opt} = \text{GD}(f, \Theta_0, \alpha, \rho)
#   \end{equation}
# where $f$ is a function returning the cost and its gradient with respect to parameter vector $\Theta$, $\Theta_0$ is the initial value, and $\alpha$
# is the learning rate. You can assume that $\alpha$. remains constant during the optimization. $\rho$ is stop condition. \\
# Then, use the GD algorithm to find the optimum of the [Rosenbrock function](https://en.wikipedia.org/wiki/Rosenbrock_function) (Consider $a=1, b=100$).
#  \\
# Also, plot the values found by GD at subsequent iterations.
#
# ## 2. Newton's Method
# Newton's method is an iterative optimization algorithm used to find the minimum of a function.
# The basic update step in Newton's method is given by:
#
# \begin{equation}
# \Theta = \Theta - H^{-1} \cdot \nabla f(\Theta)
# \end{equation}
#
#
# Where  $ H $ is the Hessian matrix of the function at $ \Theta $, and $ H^{-1} $ is the inverse of the Hessian matrix, used to adjust the step size and direction more accurately than just using the gradient alone (as done in gradient descent).
#
# #### Line Search
# Sometimes, Newton's method may take too large of a step, which can lead to divergence. To prevent this, a simple **line search** is used. This reduces the step size $ \alpha $ if the function value doesn't improve after the step.
#
# Steps:
# 1. Compute the gradient and Hessian matrix at the current point.
# 2. Calculate the step direction by multiplying the inverse of the Hessian with the gradient.
# 3. Update the point by subtracting the step from the current point.
# 4. If the function value doesn't improve, reduce the step size $ \alpha $.
# 5. Repeat until the gradient becomes sufficiently small (close to zero), indicating convergence.
#
#
#
# **Task2:** Implement Newton's method and compare it with the gradient descent. You will also need to implement a line search alogithm, e.g. (https://en.wikipedia.org/wiki/Backtracking_line_search) and make sure that the Newton's direction is indeed one along which the function is minimized.

# %%
def rosenbrock(x):
    """Returns the value and gradient of Rosenbrock's function at x: 2d vector"""
    a = 1
    b = 100
    val = (a - x[0])**2 + b * (x[1] - x[0]**2)**2
    dv_dx0 = -2 * (a - x[0]) - 4 * b * x[0] * (x[1] - x[0]**2)
    dv_dx1 = 2 * b * (x[1] - x[0]**2)
    grad = np.array([dv_dx0, dv_dx1])

    return val, grad

def rosenbrock_hessian(x):
    """Returns the value, gradient and hessian of Rosenbrock's function at x: 2d vector"""
    val, grad = rosenbrock(x)

    # Hessian matrix components
    a = 1
    b = 100
    d2v_dx0x0 = 2 - 4 * b * x[1] + 12 * b * x[0]**2
    d2v_dx0x1 = -4 * b * x[0]
    d2v_dx1x0 = d2v_dx0x1
    d2v_dx1x1 = 2 * b

    # Hessian matrix
    hessian = np.array([[d2v_dx0x0, d2v_dx0x1],
                        [d2v_dx1x0, d2v_dx1x1]])

    return val, grad, hessian


def GD(f, theta0, alpha, stop_tolerance=1e-10, max_steps=1000000):
    """Runs gradient descent algorithm on f.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, dv_dtheta) with dValuedTheta of the same shape
            as Theta
        theta0: starting point
        alpha: step length
        stop_tolerance: stop iterations when improvement is below this threshold
        max_steps: maximum number of steps
    Returns:
        tuple:
        - theta: optimum theta found by the algorithm
        - history: list of length num_steps containing tuples (theta, (val, dv_dtheta: np.array))

    """
    history = []

    theta = theta0

    step = 0
    while step < max_steps:
        val, grad = f(theta)
        theta = theta - alpha * grad
        history.append((theta.copy(), (val, grad)))
        
        if np.linalg.norm(grad) < stop_tolerance:
            break
        
        step += 1

    return theta, history

# %%
# Find the optimum of rosenbrock function

X0 = [0., 2.]
Xopt, Xhist = GD(rosenbrock, X0, alpha=1e-3, stop_tolerance=1e-10, max_steps=1e6)

print("Found optimum at %s in %d steps (true minimum is at [1,1])" % (Xopt, len(Xhist)))

# Plot how the value changes over iterations
values = [val for _, (val, _) in Xhist]

plt.plot(values)
plt.xlabel('Iteration')
plt.ylabel('Function Value')
plt.title('Gradient Descent Optimization of Rosenbrock Function')
plt.show()
# Out:
# Found optimum at [1. 1.] in 54320 steps (true minimum is at [1,1])

# %%
def Newton(f, theta0, alpha=1, stop_tolerance=1e-10, max_steps=1000000):
    """Performs Newton's optimization method with a simple line search.

    Args:
        f: function that when evaluated on a Theta of same dtype and shape as Theta0
            returns a tuple (value, gradient, hessian), where gradient and Hessian
            have the same shape as Theta.
        theta0: starting point.
        alpha: step length for backtracking line search (default is 1).
        stop_tolerance: stop iterations when the norm of the gradient is below this threshold.
        max_steps: maximum number of iterations.
    Returns:
        tuple:
        - theta: optimal Theta after convergence or maximum steps.
        - history: list of tuples (theta, value, gradient) containing the optimization path.
    """
    theta = np.array(theta0, dtype=float)
    history = []

    for step in range(max_steps):
        val, grad, hessian = f(theta)
        history.append((theta.copy(), val, grad))

        if np.linalg.norm(grad) < stop_tolerance:
            break

        try:
            hessian_inv = np.linalg.inv(hessian)
        except np.linalg.LinAlgError:
            print("Hessian is singular, stopping optimization.")
            break

        delta_theta = -hessian_inv @ grad

        t = alpha
        while t > 1e-10:
            new_theta = theta + t * delta_theta
            new_val, _, _ = f(new_theta)
            if new_val < val:
                theta = new_theta
                break
            t *= 0.5
        else:
            print("Line search failed, stopping optimization.")
            break

    return theta, history

# Test Newton's method on the Rosenbrock function
X0 = [0., 2.]  # Initial guess
Xopt, Xhist = Newton(rosenbrock_hessian, X0)

print("Found optimum at %s (true minimum is at [1,1])" % Xopt)
# Out:
# Found optimum at [1. 1.] (true minimum is at [1,1])

# %% [markdown]
# # Part two: MLP for MNIST Classification
# In this part, we are going to use `PyTorch`. If you want to become more familiar with it, check this resource: https://www.learnpytorch.io/
#
# #### In this homework, you need to
# - implement SGD optimizer (`./optimizer.py`)
# - implement forward and backward for FCLayer (`layers.py`)
# - implement forward and backward for SigmoidLayer (`layers.py`)
# - implement forward and backward for ReLULayer (`layers.py`)
# - implement forward and backward for DropoutLayer (`layers.py`)
# - implement train and test process (`solver.py`)

# %%
from layers import FCLayer, SigmoidLayer, ReLULayer
from solver import train, test
from optimizer import SGD

# %%
seed = 42
torch.manual_seed(seed)
np.random.seed(seed)
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
# Load MNIST dataset

# Converts PIL image to tensor and scales to [0, 1] and flatten it
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: x.view(-1)),
])

# Load MNIST dataset with the defined transform
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

# One-hot encoding for labels
def decode_label(label, num_classes=10):
    return torch.nn.functional.one_hot(torch.tensor(label), num_classes=num_classes).float()

# Preprocess labels and combine with transformed images
y_train = [decode_label(label) for _, label in train_dataset]
y_test = [decode_label(label) for _, label in test_dataset]

# Convert the data into tensor datasets for training and testing
train_dataset = TensorDataset(torch.stack([img for img, _ in train_dataset]), torch.stack(y_train))
test_dataset = TensorDataset(torch.stack([img for img, _ in test_dataset]), torch.stack(y_test))

# Create data loaders
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
num_epoch = 20

criterion = nn.MSELoss()

# Build MLP with FCLayer and SigmoidLayer you've implemented in layers.py
sigmoidMLP = nn.Sequential(
    FCLayer(784, 128),
    SigmoidLayer(),
    FCLayer(128, 10)
)

# Initialize optimizer you've implemented in optimizer.py
sgd = SGD(params=sigmoidMLP.parameters(), learning_rate=0.01)

# Train the model using train function you've implemented in solver.py
sigmoidMLP = train(sigmoidMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0771, Average training accuracy: 0.4956
#
# Epoch [1] Average training loss: 0.0556, Average training accuracy: 0.7378
#
# Epoch [2] Average training loss: 0.0506, Average training accuracy: 0.7835
#
# Epoch [3] Average training loss: 0.0482, Average training accuracy: 0.8046
#
# Epoch [4] Average training loss: 0.0466, Average training accuracy: 0.8173
#
# Epoch [5] Average training loss: 0.0456, Average training accuracy: 0.8254
#
# Epoch [6] Average training loss: 0.0448, Average training accuracy: 0.8307
#
# Epoch [7] Average training loss: 0.0442, Average training accuracy: 0.8344
#
# Epoch [8] Average training loss: 0.0437, Average training accuracy: 0.8384
#
# Epoch [9] Average training loss: 0.0432, Average training accuracy: 0.8408
#
# Epoch [10] Average training loss: 0.0429, Average training accuracy: 0.8430
#
# Epoch [11] Average training loss: 0.0426, Average training accuracy: 0.8455
#
# Epoch [12] Average training loss: 0.0423, Average training accuracy: 0.8465
#
# Epoch [13] Average training loss: 0.0420, Average training accuracy: 0.8474
#
# Epoch [14] Average training loss: 0.0418, Average training accuracy: 0.8489
#
# Epoch [15] Average training loss: 0.0415, Average training accuracy: 0.8504
#
# Epoch [16] Average training loss: 0.0413, Average training accuracy: 0.8517
#
# Epoch [17] Average training loss: 0.0411, Average training accuracy: 0.8514
#
# Epoch [18] Average training loss: 0.0409, Average training accuracy: 0.8529
#
# Epoch [19] Average training loss: 0.0407, Average training accuracy: 0.8533

# %%
# Test your model using test function you've implemented in solver.py
test(sigmoidMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.8627.

# %%
# Build MLP with FCLayer and ReLULayer
reluMLP = nn.Sequential(
    FCLayer(784, 128),
    ReLULayer(),
    FCLayer(128, 10)
)

# Initialize optimizer
sgd = SGD(reluMLP.parameters(), learning_rate=0.01)

# Train the model
reluMLP = train(reluMLP, criterion, sgd, train_dataloader, num_epoch, device=device)
# Out:
# Epoch [0] Average training loss: 0.0712, Average training accuracy: 0.6373
#
# Epoch [1] Average training loss: 0.0467, Average training accuracy: 0.8230
#
# Epoch [2] Average training loss: 0.0399, Average training accuracy: 0.8589
#
# Epoch [3] Average training loss: 0.0357, Average training accuracy: 0.8765
#
# Epoch [4] Average training loss: 0.0327, Average training accuracy: 0.8875
#
# Epoch [5] Average training loss: 0.0305, Average training accuracy: 0.8953
#
# Epoch [6] Average training loss: 0.0288, Average training accuracy: 0.9011
#
# Epoch [7] Average training loss: 0.0274, Average training accuracy: 0.9060
#
# Epoch [8] Average training loss: 0.0262, Average training accuracy: 0.9102
#
# Epoch [9] Average training loss: 0.0253, Average training accuracy: 0.9131
#
# Epoch [10] Average training loss: 0.0244, Average training accuracy: 0.9162
#
# Epoch [11] Average training loss: 0.0237, Average training accuracy: 0.9185
#
# Epoch [12] Average training loss: 0.0231, Average training accuracy: 0.9205
#
# Epoch [13] Average training loss: 0.0225, Average training accuracy: 0.9226
#
# Epoch [14] Average training loss: 0.0220, Average training accuracy: 0.9247
#
# Epoch [15] Average training loss: 0.0215, Average training accuracy: 0.9264
#
# Epoch [16] Average training loss: 0.0211, Average training accuracy: 0.9279
#
# Epoch [17] Average training loss: 0.0207, Average training accuracy: 0.9288
#
# Epoch [18] Average training loss: 0.0204, Average training accuracy: 0.9298
#
# Epoch [19] Average training loss: 0.0200, Average training accuracy: 0.9309

# %%
# Test the model
test(reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.9312.

# %% [markdown]
# ### Overfit the model
# Try to overfit the reluMLP model. You can make the model as complex as you like, use subset of the data for training or any other approach you want.
# Then add **DropoutLayer** to your model in order to reduce overfitting problem.

# %%
#TODO: overfit the reluMLP model
from torch.utils.data import DataLoader, Subset
import torch.nn as nn
import torch.optim as optim
from layers import FCLayer, ReLULayer, DropoutLayer  # Assuming these are your custom layers

# Step 1: Overfit the model by increasing complexity and using a data subset

# Define a more complex reluMLP model to encourage overfitting
complex_reluMLP = nn.Sequential(
    FCLayer(784, 256),
    ReLULayer(),
    FCLayer(256, 256),
    ReLULayer(),
    FCLayer(256, 128),
    ReLULayer(),
    FCLayer(128, 64),
    ReLULayer(),
    FCLayer(64, 10)
)

subset_size = int(0.1 * len(train_dataset))
subset_indices = list(range(subset_size))
subset_train_dataset = Subset(train_dataset, subset_indices)
subset_train_dataloader = DataLoader(subset_train_dataset, batch_size=64, shuffle=True)

sgd_complex = SGD(complex_reluMLP.parameters(), learning_rate=0.01)

complex_reluMLP = train(complex_reluMLP, criterion, sgd_complex, subset_train_dataloader, 100, device=device)
# Out:
# Epoch [0] Average training loss: 0.0983, Average training accuracy: 0.1675
#
# Epoch [1] Average training loss: 0.0862, Average training accuracy: 0.3090
#
# Epoch [2] Average training loss: 0.0806, Average training accuracy: 0.4077
#
# Epoch [3] Average training loss: 0.0766, Average training accuracy: 0.4694
#
# Epoch [4] Average training loss: 0.0732, Average training accuracy: 0.5202
#
# Epoch [5] Average training loss: 0.0702, Average training accuracy: 0.5609
#
# Epoch [6] Average training loss: 0.0675, Average training accuracy: 0.5968
#
# Epoch [7] Average training loss: 0.0651, Average training accuracy: 0.6246
#
# Epoch [8] Average training loss: 0.0627, Average training accuracy: 0.6532
#
# Epoch [9] Average training loss: 0.0605, Average training accuracy: 0.6765
#
# Epoch [10] Average training loss: 0.0585, Average training accuracy: 0.6953
#
# Epoch [11] Average training loss: 0.0566, Average training accuracy: 0.7114
#
# Epoch [12] Average training loss: 0.0548, Average training accuracy: 0.7270
#
# Epoch [13] Average training loss: 0.0532, Average training accuracy: 0.7433
#
# Epoch [14] Average training loss: 0.0516, Average training accuracy: 0.7539
#
# Epoch [15] Average training loss: 0.0502, Average training accuracy: 0.7647
#
# Epoch [16] Average training loss: 0.0488, Average training accuracy: 0.7757
#
# Epoch [17] Average training loss: 0.0476, Average training accuracy: 0.7830
#
# Epoch [18] Average training loss: 0.0464, Average training accuracy: 0.7927
#
# Epoch [19] Average training loss: 0.0453, Average training accuracy: 0.7986
#
# Epoch [20] Average training loss: 0.0443, Average training accuracy: 0.8068
#
# Epoch [21] Average training loss: 0.0434, Average training accuracy: 0.8152
#
# Epoch [22] Average training loss: 0.0425, Average training accuracy: 0.8213
#
# Epoch [23] Average training loss: 0.0417, Average training accuracy: 0.8272
#
# Epoch [24] Average training loss: 0.0409, Average training accuracy: 0.8326
#
# Epoch [25] Average training loss: 0.0401, Average training accuracy: 0.8384
#
# Epoch [26] Average training loss: 0.0394, Average training accuracy: 0.8438
#
# Epoch [27] Average training loss: 0.0387, Average training accuracy: 0.8482
#
# Epoch [28] Average training loss: 0.0381, Average training accuracy: 0.8527
#
# Epoch [29] Average training loss: 0.0375, Average training accuracy: 0.8567
#
# Epoch [30] Average training loss: 0.0369, Average training accuracy: 0.8605
#
# Epoch [31] Average training loss: 0.0364, Average training accuracy: 0.8620
#
# Epoch [32] Average training loss: 0.0359, Average training accuracy: 0.8646
#
# Epoch [33] Average training loss: 0.0354, Average training accuracy: 0.8676
#
# Epoch [34] Average training loss: 0.0349, Average training accuracy: 0.8705
#
# Epoch [35] Average training loss: 0.0345, Average training accuracy: 0.8745
#
# Epoch [36] Average training loss: 0.0340, Average training accuracy: 0.8758
#
# Epoch [37] Average training loss: 0.0336, Average training accuracy: 0.8785
#
# Epoch [38] Average training loss: 0.0332, Average training accuracy: 0.8815
#
# Epoch [39] Average training loss: 0.0328, Average training accuracy: 0.8834
#
# Epoch [40] Average training loss: 0.0325, Average training accuracy: 0.8851
#
# Epoch [41] Average training loss: 0.0321, Average training accuracy: 0.8864
#
# Epoch [42] Average training loss: 0.0318, Average training accuracy: 0.8896
#
# Epoch [43] Average training loss: 0.0314, Average training accuracy: 0.8920
#
# Epoch [44] Average training loss: 0.0311, Average training accuracy: 0.8933
#
# Epoch [45] Average training loss: 0.0308, Average training accuracy: 0.8952
#
# Epoch [46] Average training loss: 0.0305, Average training accuracy: 0.8954
#
# Epoch [47] Average training loss: 0.0302, Average training accuracy: 0.8966
#
# Epoch [48] Average training loss: 0.0299, Average training accuracy: 0.8973
#
# Epoch [49] Average training loss: 0.0296, Average training accuracy: 0.8991
#
# Epoch [50] Average training loss: 0.0293, Average training accuracy: 0.9011
#
# Epoch [51] Average training loss: 0.0291, Average training accuracy: 0.9012
#
# Epoch [52] Average training loss: 0.0288, Average training accuracy: 0.9029
#
# Epoch [53] Average training loss: 0.0286, Average training accuracy: 0.9038
#
# Epoch [54] Average training loss: 0.0283, Average training accuracy: 0.9050
#
# Epoch [55] Average training loss: 0.0281, Average training accuracy: 0.9057
#
# Epoch [56] Average training loss: 0.0278, Average training accuracy: 0.9070
#
# Epoch [57] Average training loss: 0.0276, Average training accuracy: 0.9076
#
# Epoch [58] Average training loss: 0.0274, Average training accuracy: 0.9090
#
# Epoch [59] Average training loss: 0.0272, Average training accuracy: 0.9096
#
# Epoch [60] Average training loss: 0.0270, Average training accuracy: 0.9111
#
# Epoch [61] Average training loss: 0.0268, Average training accuracy: 0.9116
#
# Epoch [62] Average training loss: 0.0266, Average training accuracy: 0.9118
#
# Epoch [63] Average training loss: 0.0264, Average training accuracy: 0.9143
#
# Epoch [64] Average training loss: 0.0262, Average training accuracy: 0.9143
#
# Epoch [65] Average training loss: 0.0260, Average training accuracy: 0.9146
#
# Epoch [66] Average training loss: 0.0258, Average training accuracy: 0.9152
#
# Epoch [67] Average training loss: 0.0257, Average training accuracy: 0.9159
#
# Epoch [68] Average training loss: 0.0255, Average training accuracy: 0.9166
#
# Epoch [69] Average training loss: 0.0253, Average training accuracy: 0.9177
#
# Epoch [70] Average training loss: 0.0251, Average training accuracy: 0.9186
#
# Epoch [71] Average training loss: 0.0250, Average training accuracy: 0.9197
#
# Epoch [72] Average training loss: 0.0248, Average training accuracy: 0.9194
#
# Epoch [73] Average training loss: 0.0247, Average training accuracy: 0.9207
#
# Epoch [74] Average training loss: 0.0245, Average training accuracy: 0.9210
#
# Epoch [75] Average training loss: 0.0243, Average training accuracy: 0.9207
#
# Epoch [76] Average training loss: 0.0242, Average training accuracy: 0.9221
#
# Epoch [77] Average training loss: 0.0240, Average training accuracy: 0.9227
#
# Epoch [78] Average training loss: 0.0239, Average training accuracy: 0.9230
#
# Epoch [79] Average training loss: 0.0238, Average training accuracy: 0.9239
#
# Epoch [80] Average training loss: 0.0236, Average training accuracy: 0.9238
#
# Epoch [81] Average training loss: 0.0235, Average training accuracy: 0.9239
#
# Epoch [82] Average training loss: 0.0233, Average training accuracy: 0.9258
#
# Epoch [83] Average training loss: 0.0232, Average training accuracy: 0.9264
#
# Epoch [84] Average training loss: 0.0231, Average training accuracy: 0.9270
#
# Epoch [85] Average training loss: 0.0230, Average training accuracy: 0.9264
#
# Epoch [86] Average training loss: 0.0228, Average training accuracy: 0.9276
#
# Epoch [87] Average training loss: 0.0227, Average training accuracy: 0.9275
#
# Epoch [88] Average training loss: 0.0226, Average training accuracy: 0.9291
#
# Epoch [89] Average training loss: 0.0225, Average training accuracy: 0.9301
#
# Epoch [90] Average training loss: 0.0223, Average training accuracy: 0.9292
#
# Epoch [91] Average training loss: 0.0222, Average training accuracy: 0.9311
#
# Epoch [92] Average training loss: 0.0221, Average training accuracy: 0.9310
#
# Epoch [93] Average training loss: 0.0220, Average training accuracy: 0.9305
#
# Epoch [94] Average training loss: 0.0219, Average training accuracy: 0.9314
#
# Epoch [95] Average training loss: 0.0218, Average training accuracy: 0.9323
#
# Epoch [96] Average training loss: 0.0217, Average training accuracy: 0.9322
#
# Epoch [97] Average training loss: 0.0216, Average training accuracy: 0.9330
#
# Epoch [98] Average training loss: 0.0215, Average training accuracy: 0.9332
#
# Epoch [99] Average training loss: 0.0213, Average training accuracy: 0.9340

# %%
test(complex_reluMLP, test_dataloader, device)
# Out:
# The test accuracy is 0.9075.

# %%
complex_reluMLP_with_dropout = nn.Sequential(
    FCLayer(784, 256),
    ReLULayer(),
    DropoutLayer(0.2),
    FCLayer(256, 256),
    ReLULayer(),
    DropoutLayer(0.2),
    FCLayer(256, 128),
    ReLULayer(),
    DropoutLayer(0.2),
    FCLayer(128, 64),
    ReLULayer(),
    DropoutLayer(0.2),
    FCLayer(64, 10)
)

sgd_complex_with_dropout = SGD(complex_reluMLP_with_dropout.parameters(), learning_rate=0.01)

complex_reluMLP_with_dropout = train(complex_reluMLP_with_dropout, criterion, sgd_complex_with_dropout, subset_train_dataloader, 100, device=device)
# Out:
# Epoch [0] Average training loss: 0.1417, Average training accuracy: 0.1102
#
# Epoch [1] Average training loss: 0.1074, Average training accuracy: 0.1345
#
# Epoch [2] Average training loss: 0.1008, Average training accuracy: 0.1515
#
# Epoch [3] Average training loss: 0.0967, Average training accuracy: 0.1661
#
# Epoch [4] Average training loss: 0.0946, Average training accuracy: 0.1827
#
# Epoch [5] Average training loss: 0.0929, Average training accuracy: 0.1928
#
# Epoch [6] Average training loss: 0.0915, Average training accuracy: 0.2082
#
# Epoch [7] Average training loss: 0.0909, Average training accuracy: 0.2098
#
# Epoch [8] Average training loss: 0.0891, Average training accuracy: 0.2429
#
# Epoch [9] Average training loss: 0.0884, Average training accuracy: 0.2475
#
# Epoch [10] Average training loss: 0.0875, Average training accuracy: 0.2615
#
# Epoch [11] Average training loss: 0.0869, Average training accuracy: 0.2773
#
# Epoch [12] Average training loss: 0.0858, Average training accuracy: 0.2939
#
# Epoch [13] Average training loss: 0.0854, Average training accuracy: 0.3040
#
# Epoch [14] Average training loss: 0.0842, Average training accuracy: 0.3220
#
# Epoch [15] Average training loss: 0.0840, Average training accuracy: 0.3341
#
# Epoch [16] Average training loss: 0.0830, Average training accuracy: 0.3528
#
# Epoch [17] Average training loss: 0.0823, Average training accuracy: 0.3663
#
# Epoch [18] Average training loss: 0.0818, Average training accuracy: 0.3797
#
# Epoch [19] Average training loss: 0.0815, Average training accuracy: 0.3741
#
# Epoch [20] Average training loss: 0.0810, Average training accuracy: 0.3846
#
# Epoch [21] Average training loss: 0.0803, Average training accuracy: 0.3958
#
# Epoch [22] Average training loss: 0.0796, Average training accuracy: 0.4049
#
# Epoch [23] Average training loss: 0.0790, Average training accuracy: 0.4144
#
# Epoch [24] Average training loss: 0.0784, Average training accuracy: 0.4306
#
# Epoch [25] Average training loss: 0.0783, Average training accuracy: 0.4256
#
# Epoch [26] Average training loss: 0.0772, Average training accuracy: 0.4444
#
# Epoch [27] Average training loss: 0.0766, Average training accuracy: 0.4582
#
# Epoch [28] Average training loss: 0.0764, Average training accuracy: 0.4573
#
# Epoch [29] Average training loss: 0.0759, Average training accuracy: 0.4647
#
# Epoch [30] Average training loss: 0.0754, Average training accuracy: 0.4725
#
# Epoch [31] Average training loss: 0.0749, Average training accuracy: 0.4785
#
# Epoch [32] Average training loss: 0.0743, Average training accuracy: 0.4875
#
# Epoch [33] Average training loss: 0.0742, Average training accuracy: 0.4953
#
# Epoch [34] Average training loss: 0.0734, Average training accuracy: 0.4945
#
# Epoch [35] Average training loss: 0.0730, Average training accuracy: 0.5029
#
# Epoch [36] Average training loss: 0.0727, Average training accuracy: 0.5084
#
# Epoch [37] Average training loss: 0.0723, Average training accuracy: 0.5116
#
# Epoch [38] Average training loss: 0.0717, Average training accuracy: 0.5207
#
# Epoch [39] Average training loss: 0.0715, Average training accuracy: 0.5204
#
# Epoch [40] Average training loss: 0.0707, Average training accuracy: 0.5346
#
# Epoch [41] Average training loss: 0.0701, Average training accuracy: 0.5463
#
# Epoch [42] Average training loss: 0.0701, Average training accuracy: 0.5373
#
# Epoch [43] Average training loss: 0.0695, Average training accuracy: 0.5577
#
# Epoch [44] Average training loss: 0.0694, Average training accuracy: 0.5558
#
# Epoch [45] Average training loss: 0.0687, Average training accuracy: 0.5585
#
# Epoch [46] Average training loss: 0.0682, Average training accuracy: 0.5723
#
# Epoch [47] Average training loss: 0.0679, Average training accuracy: 0.5647
#
# Epoch [48] Average training loss: 0.0679, Average training accuracy: 0.5671
#
# Epoch [49] Average training loss: 0.0669, Average training accuracy: 0.5818
#
# Epoch [50] Average training loss: 0.0669, Average training accuracy: 0.5782
#
# Epoch [51] Average training loss: 0.0668, Average training accuracy: 0.5839
#
# Epoch [52] Average training loss: 0.0663, Average training accuracy: 0.5886
#
# Epoch [53] Average training loss: 0.0660, Average training accuracy: 0.5947
#
# Epoch [54] Average training loss: 0.0656, Average training accuracy: 0.5988
#
# Epoch [55] Average training loss: 0.0650, Average training accuracy: 0.6024
#
# Epoch [56] Average training loss: 0.0649, Average training accuracy: 0.6042
#
# Epoch [57] Average training loss: 0.0647, Average training accuracy: 0.6012
#
# Epoch [58] Average training loss: 0.0641, Average training accuracy: 0.6172
#
# Epoch [59] Average training loss: 0.0640, Average training accuracy: 0.6123
#
# Epoch [60] Average training loss: 0.0639, Average training accuracy: 0.6161
#
# Epoch [61] Average training loss: 0.0637, Average training accuracy: 0.6207
#
# Epoch [62] Average training loss: 0.0632, Average training accuracy: 0.6228
#
# Epoch [63] Average training loss: 0.0630, Average training accuracy: 0.6238
#
# Epoch [64] Average training loss: 0.0624, Average training accuracy: 0.6356
#
# Epoch [65] Average training loss: 0.0621, Average training accuracy: 0.6312
#
# Epoch [66] Average training loss: 0.0620, Average training accuracy: 0.6379
#
# Epoch [67] Average training loss: 0.0619, Average training accuracy: 0.6353
#
# Epoch [68] Average training loss: 0.0613, Average training accuracy: 0.6510
#
# Epoch [69] Average training loss: 0.0610, Average training accuracy: 0.6470
#
# Epoch [70] Average training loss: 0.0611, Average training accuracy: 0.6459
#
# Epoch [71] Average training loss: 0.0608, Average training accuracy: 0.6521
#
# Epoch [72] Average training loss: 0.0607, Average training accuracy: 0.6538
#
# Epoch [73] Average training loss: 0.0604, Average training accuracy: 0.6586
#
# Epoch [74] Average training loss: 0.0602, Average training accuracy: 0.6555
#
# Epoch [75] Average training loss: 0.0593, Average training accuracy: 0.6657
#
# Epoch [76] Average training loss: 0.0596, Average training accuracy: 0.6643
#
# Epoch [77] Average training loss: 0.0594, Average training accuracy: 0.6636
#
# Epoch [78] Average training loss: 0.0590, Average training accuracy: 0.6708
#
# Epoch [79] Average training loss: 0.0587, Average training accuracy: 0.6753
#
# Epoch [80] Average training loss: 0.0585, Average training accuracy: 0.6717
#
# Epoch [81] Average training loss: 0.0586, Average training accuracy: 0.6749
#
# Epoch [82] Average training loss: 0.0580, Average training accuracy: 0.6818
#
# Epoch [83] Average training loss: 0.0578, Average training accuracy: 0.6820
#
# Epoch [84] Average training loss: 0.0575, Average training accuracy: 0.6875
#
# Epoch [85] Average training loss: 0.0573, Average training accuracy: 0.6827
#
# Epoch [86] Average training loss: 0.0575, Average training accuracy: 0.6866
#
# Epoch [87] Average training loss: 0.0573, Average training accuracy: 0.6960
#
# Epoch [88] Average training loss: 0.0564, Average training accuracy: 0.7014
#
# Epoch [89] Average training loss: 0.0569, Average training accuracy: 0.6911
#
# Epoch [90] Average training loss: 0.0567, Average training accuracy: 0.6910
#
# Epoch [91] Average training loss: 0.0563, Average training accuracy: 0.6991
#
# Epoch [92] Average training loss: 0.0563, Average training accuracy: 0.6956
#
# Epoch [93] Average training loss: 0.0558, Average training accuracy: 0.7025
#
# Epoch [94] Average training loss: 0.0557, Average training accuracy: 0.6982
#
# Epoch [95] Average training loss: 0.0552, Average training accuracy: 0.7061
#
# Epoch [96] Average training loss: 0.0551, Average training accuracy: 0.7080
#
# Epoch [97] Average training loss: 0.0550, Average training accuracy: 0.7153
#
# Epoch [98] Average training loss: 0.0548, Average training accuracy: 0.7108
#
# Epoch [99] Average training loss: 0.0549, Average training accuracy: 0.7102

# %%
test(complex_reluMLP_with_dropout, test_dataloader, device)
# Out:
# The test accuracy is 0.7871.
